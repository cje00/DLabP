# %%
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen
from selenium import webdriver
from datetime import datetime, timedelta
import time

#에러 나면 webdriver 호출하는 코드들을 아래 코드로 변경 및 라이브러리 추가
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service

driver=webdriver.Chrome(options=Options(), service=Service('C:/Users/thkim/Downloads/chromedriver_win32'))

pd.set_option('display.max_colwidth',None)
row = pd.Series(['날짜','운영시간','운휴 목록'])
df = pd.DataFrame(columns = row)
col = df.columns

#운휴목록
date = datetime.now()
url="https://adventure.lotteworld.com/kor/usage-guide/service/index.do?oprtDt="
for i in range(4):
    temp_date = (date+timedelta(days=i)).strftime("%Y%m%d")
    html = driver.get(url+temp_date)
    time.sleep(3)
    page = driver.page_source
    bs_obj = BeautifulSoup(page, "html.parser")
   
    closed_list = []
    for closed in bs_obj.find("ul", {"class":"holidayList"}).find_all("p", {"class":"txt"}):
        print(closed.text.splitlines())
        closed_list.append( ",".join(closed.text.splitlines()))
        
    row = pd.Series([datetime.strptime(temp_date, '%Y%m%d').strftime("%Y-%m-%d"),
        bs_obj.find("strong", {"class":"time time0"}).text + ":"
        +bs_obj.find("strong",{"class":"time time1"}).text+" ~ "
        +bs_obj.find("strong", {"class":"time time2"}).text + ":"
        +bs_obj.find("strong",{"class":"time time3"}).text,
        closed_list], index=col)
    df = df.append(row, ignore_index=True)
    #print(bs_obj.find("ul", {"class":"holidayList"}).text)

df
# Out:
# ['어린이 동화극장']
# ['신밧드의모험']
# ['어크로스다크']
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\2513363206.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# ['어린이 동화극장']
# ['신밧드의모험']
# ['자이로드롭']
# ['어크로스다크']
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\2513363206.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# ['파라오의 분노']
# ['와일드 정글']
# ['어크로스다크']
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\2513363206.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
# ['정글탐험보트']
# ['어크로스다크']
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\2513363206.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)
#            날짜           운영시간                              운휴 목록
# 0  2023-06-27  10:00 ~ 21:00         [어린이 동화극장, 신밧드의모험, 어크로스다크]
# 1  2023-06-28  10:00 ~ 21:00  [어린이 동화극장, 신밧드의모험, 자이로드롭, 어크로스다크]
# 2  2023-06-29  10:00 ~ 21:00          [파라오의 분노, 와일드 정글, 어크로스다크]
# 3  2023-06-30  10:00 ~ 22:00                   [정글탐험보트, 어크로스다크]

# %%
pd.set_option('display.max_colwidth',None)
row = pd.Series(['혜택 종류','기간','혜택', '혜택가'])
df2 = pd.DataFrame(columns = row)
col = df2.columns

url2 = "https://adventure.lotteworld.com/kor/price/benefit/information/list.do"
html = driver.get(url2)
page = driver.page_source
bs_obj = BeautifulSoup(page, "html.parser")

benefit = bs_obj.find("div", {"class":"benefitList"})
for event in benefit.find_all("a"):
    print(list(filter(None, event.text.splitlines())))
    temp = event.text.splitlines()
    del temp[0]
    del temp[1]
    row2 = pd.Series(temp, index=col)
    df2 = df2.append(row2, ignore_index=True)
    # print(list(filter(None, event.text.splitlines())))

df2
# Out:
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '롯데월드카드로 최대 12만원 캐시백 혜택 챙겨..', '31,000원']
# ['이달의 혜택', '2023.06.09 ~ 2023.06.30', '삼성카드와 함께 삼(SAM)바 성(SUNG)지..', '33,000원']
# ['이달의 혜택', '2023.06.09 ~ 2023.07.23', '이 여름 Summer, 우리카드와 함께', '33,000원']
# ['이달의 혜택', '2023.06.16 ~ 2023.07.14', '다시 만나이 세계[지금 나이 20,000 안녕..', '20,000원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '롯데월드 최대 50% 할인 + 이용금액 100..', '최대 10만원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '제휴카드 온라인 (본인50%+추가5%)', '27,900원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '제휴카드 현장 (본인50%+추가5%)', '27,900원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', 'L.POINT 결제 우대', '33,000원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', 'SKT 멤버십(기본제휴)', '37,200원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', 'KT 멤버십(기본제휴)', '31,000원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', 'LG U+ 멤버십(여행콕)', '34,100원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '슬기로운 네이버페이 생활(온라인/모바일 예매)', '39,900원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '카카오페이로 가보자GO(온라인/모바일 예매)', '40,500원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '현대M포인트 프로모션', '18,600원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '해피한 월드 세상(해피포인트 멤버십)', '41,500원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '삼성포인트 프로모션']
# ['이달의 혜택', '2023.06.12 ~ 2023.07.09', '[롯데렌탈X롯데월드]렌터카타고 잠실부터 부산까..', '37,200원']
# ['연간 혜택', '2022.06.01 ~ 2023.06.30', '상시 우대 혜택', '최대 50% 할인']
# ['이달의 혜택', '2023.06.19 ~ 2023.06.30', '왜 6? 제가 종강한 사람처럼 보이시나6?', '27,500원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '당일 온라인/모바일 예매 우대', '41,500원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '롯데월드 완전정복', '37,000원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '롯데월드도 여름이었다..', '38,500원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '픽시매직 교복 패키지', '54,000원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '교복은 롯데월드', '42,000원']
# ['연간 혜택', '2023.06.01 ~ 2023.06.30', '문화누리카드 우대', '31,500원']
# ['이달의 혜택', '2023.06.01 ~ 2023.09.30', "호국보훈 '하늘부터 바다까지 충성!", '37,200원']
# ['연간 혜택', '2023.06.01 ~ 2023.06.30', '송파구민, 자매도시 거주민 우대', '37,200원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '연간이용 동반객 우대', '31,500원']
# ['이달의 혜택', '2023.06.01 ~ 2023.06.30', '아쿠아리움 연간이용 우대', '31,500원']
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
# C:\Users\thkim\AppData\Local\Temp\ipykernel_5100\423114984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row2, ignore_index=True)
#      혜택 종류                       기간                           혜택        혜택가
# 0   이달의 혜택  2023.06.01 ~ 2023.06.30  롯데월드카드로 최대 12만원 캐시백 혜택 챙겨..    31,000원
# 1   이달의 혜택  2023.06.09 ~ 2023.06.30  삼성카드와 함께 삼(SAM)바 성(SUNG)지..    33,000원
# 2   이달의 혜택  2023.06.09 ~ 2023.07.23        이 여름 Summer, 우리카드와 함께    33,000원
# 3   이달의 혜택  2023.06.16 ~ 2023.07.14  다시 만나이 세계[지금 나이 20,000 안녕..    20,000원
# 4   이달의 혜택  2023.06.01 ~ 2023.06.30  롯데월드 최대 50% 할인 + 이용금액 100..    최대 10만원
# 5   이달의 혜택  2023.06.01 ~ 2023.06.30        제휴카드 온라인 (본인50%+추가5%)    27,900원
# 6   이달의 혜택  2023.06.01 ~ 2023.06.30         제휴카드 현장 (본인50%+추가5%)    27,900원
# 7   이달의 혜택  2023.06.01 ~ 2023.06.30                L.POINT 결제 우대    33,000원
# 8   이달의 혜택  2023.06.01 ~ 2023.06.30                SKT 멤버십(기본제휴)    37,200원
# 9   이달의 혜택  2023.06.01 ~ 2023.06.30                 KT 멤버십(기본제휴)    31,000원
# 10  이달의 혜택  2023.06.01 ~ 2023.06.30               LG U+ 멤버십(여행콕)    34,100원
# 11  이달의 혜택  2023.06.01 ~ 2023.06.30    슬기로운 네이버페이 생활(온라인/모바일 예매)    39,900원
# 12  이달의 혜택  2023.06.01 ~ 2023.06.30     카카오페이로 가보자GO(온라인/모바일 예매)    40,500원
# 13  이달의 혜택  2023.06.01 ~ 2023.06.30                  현대M포인트 프로모션    18,600원
# 14  이달의 혜택  2023.06.01 ~ 2023.06.30         해피한 월드 세상(해피포인트 멤버십)    41,500원
# 15  이달의 혜택  2023.06.01 ~ 2023.06.30                   삼성포인트 프로모션
# 16  이달의 혜택  2023.06.12 ~ 2023.07.09  [롯데렌탈X롯데월드]렌터카타고 잠실부터 부산까..    37,200원
# 17   연간 혜택  2022.06.01 ~ 2023.06.30                     상시 우대 혜택  최대 50% 할인
# 18  이달의 혜택  2023.06.19 ~ 2023.06.30      왜 6? 제가 종강한 사람처럼 보이시나6?    27,500원
# 19  이달의 혜택  2023.06.01 ~ 2023.06.30             당일 온라인/모바일 예매 우대    41,500원
# 20  이달의 혜택  2023.06.01 ~ 2023.06.30                    롯데월드 완전정복    37,000원
# 21  이달의 혜택  2023.06.01 ~ 2023.06.30                롯데월드도 여름이었다..    38,500원
# 22  이달의 혜택  2023.06.01 ~ 2023.06.30                  픽시매직 교복 패키지    54,000원
# 23  이달의 혜택  2023.06.01 ~ 2023.06.30                     교복은 롯데월드    42,000원
# 24   연간 혜택  2023.06.01 ~ 2023.06.30                    문화누리카드 우대    31,500원
# 25  이달의 혜택  2023.06.01 ~ 2023.09.30          호국보훈 '하늘부터 바다까지 충성!    37,200원
# 26   연간 혜택  2023.06.01 ~ 2023.06.30            송파구민, 자매도시 거주민 우대    37,200원
# 27  이달의 혜택  2023.06.01 ~ 2023.06.30                  연간이용 동반객 우대    31,500원
# 28  이달의 혜택  2023.06.01 ~ 2023.06.30                아쿠아리움 연간이용 우대    31,500원

# %%
url2 = "https://adventure.lotteworld.com/kor/price/benefit/information/list.do"
html = driver.get(url2)
page = driver.page_source
bs_obj = BeautifulSoup(page, "html.parser")

benefit = bs_obj.find("div", {"class":"benefitList"})
for event in benefit.find_all("a"):
    print(event.text.splitlines())
    #print(list(filter(None, event.text.splitlines())))
# Out:
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '롯데월드카드로 최대 12만원 캐시백 혜택 챙겨..', '31,000원']
# ['', '이달의 혜택', '', '2023.06.09 ~ 2023.06.30', '삼성카드와 함께 삼(SAM)바 성(SUNG)지..', '33,000원']
# ['', '이달의 혜택', '', '2023.06.09 ~ 2023.07.23', '이 여름 Summer, 우리카드와 함께', '33,000원']
# ['', '이달의 혜택', '', '2023.06.16 ~ 2023.07.14', '다시 만나이 세계[지금 나이 20,000 안녕..', '20,000원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '롯데월드 최대 50% 할인 + 이용금액 100..', '최대 10만원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '제휴카드 온라인 (본인50%+추가5%)', '27,900원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '제휴카드 현장 (본인50%+추가5%)', '27,900원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', 'L.POINT 결제 우대', '33,000원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', 'SKT 멤버십(기본제휴)', '37,200원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', 'KT 멤버십(기본제휴)', '31,000원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', 'LG U+ 멤버십(여행콕)', '34,100원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '슬기로운 네이버페이 생활(온라인/모바일 예매)', '39,900원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '카카오페이로 가보자GO(온라인/모바일 예매)', '40,500원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '현대M포인트 프로모션', '18,600원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '해피한 월드 세상(해피포인트 멤버십)', '41,500원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '삼성포인트 프로모션', '']
# ['', '이달의 혜택', '', '2023.06.12 ~ 2023.07.09', '[롯데렌탈X롯데월드]렌터카타고 잠실부터 부산까..', '37,200원']
# ['', '연간 혜택', '', '2022.06.01 ~ 2023.06.30', '상시 우대 혜택', '최대 50% 할인']
# ['', '이달의 혜택', '', '2023.06.19 ~ 2023.06.30', '왜 6? 제가 종강한 사람처럼 보이시나6?', '27,500원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '당일 온라인/모바일 예매 우대', '41,500원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '롯데월드 완전정복', '37,000원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '롯데월드도 여름이었다..', '38,500원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '픽시매직 교복 패키지', '54,000원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '교복은 롯데월드', '42,000원']
# ['', '연간 혜택', '', '2023.06.01 ~ 2023.06.30', '문화누리카드 우대', '31,500원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.09.30', "호국보훈 '하늘부터 바다까지 충성!", '37,200원']
# ['', '연간 혜택', '', '2023.06.01 ~ 2023.06.30', '송파구민, 자매도시 거주민 우대', '37,200원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '연간이용 동반객 우대', '31,500원']
# ['', '이달의 혜택', '', '2023.06.01 ~ 2023.06.30', '아쿠아리움 연간이용 우대', '31,500원']
